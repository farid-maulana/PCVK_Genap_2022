# %% [markdown]
# <a href="https://colab.research.google.com/github/farid-maulana/PCVK_Genap_2022/blob/main/Week8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # **Fungsi Dilasi**

# %%
img = cv.imread('/content/drive/MyDrive/Images/j.png')

kernel = np.ones((5,5), np.uint8)
dilation = cv.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8ef0fe5390>,
#  <matplotlib.image.AxesImage at 0x7f8ef0fcbd10>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %% [markdown]
# # **Fungsi erosi**

# %%
img1= cv.imread('/content/drive/MyDrive/Images/j.png', 0)

m,n= img1.shape 

plt.imshow(img1, cmap="gray")

k=5
SE= np.ones((k,k), dtype=np.uint8)
constant= (k-1)//2

imgErode= np.zeros((m,n), dtype=np.uint8)

for i in range(constant, m-constant):
  for j in range(constant,n-constant):
    temp= img1[i-constant:i+constant+1, j-constant:j+constant+1]
    product= temp*SE
    imgErode[i,j]= np.min(product)
plt.subplot(121), plt.imshow(img1, cmap ="gray"), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(imgErode, cmap="gray"), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8ef0fda210>,
#  <matplotlib.image.AxesImage at 0x7f8ef09dac90>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %% [markdown]
# # **Dilasi dengan library**

# %%
kernel = np.ones((5,5), np.uint8)
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8ef0a5a310>,
#  <matplotlib.image.AxesImage at 0x7f8ef097fb50>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %% [markdown]
# # **Erosi dengan Library**

# %%
kernel = np.ones((5,5), np.uint8)
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8ef098b0d0>,
#  <matplotlib.image.AxesImage at 0x7f8ef08638d0>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %% [markdown]
# # **Operasi Opening**

# %%
kernel = np.ones((7,7), np.uint8)
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening), plt.title('Citra Hasil Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8ef0f18190>,
#  <matplotlib.image.AxesImage at 0x7f8ef0905e90>,
#  Text(0.5, 1.0, 'Citra Hasil Opening'))

# %% [markdown]
# # **Operasi Closing**

# %%
kernel = np.ones((7,7), np.uint8)
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(closing), plt.title('Citra Hasil Closing')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8ef0944250>,
#  <matplotlib.image.AxesImage at 0x7f8ef06e3b50>,
#  Text(0.5, 1.0, 'Citra Hasil Closing'))

# %% [markdown]
# ## **Dilasi Cross 3x3**

# %%
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (3, 3))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi 3x3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8ef06f10d0>,
#  <matplotlib.image.AxesImage at 0x7f8ef0639c10>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi 3x3'))

# %% [markdown]
# ## **Dilasi Cross 5x5**

# %%
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (5, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi 5x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8ef05c4450>,
#  <matplotlib.image.AxesImage at 0x7f8ef050fc90>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi 5x5'))

# %% [markdown]
# ## **Dilasi Circular 7x7**

# %%
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (7,7))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Circular 7x7')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8ef065be50>,
#  <matplotlib.image.AxesImage at 0x7f8ef0294590>,
#  Text(0.5, 1.0, 'Citra Hasil Circular 7x7'))

# %% [markdown]
# ## **Dilasi Circular 9x9**

# %%
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (9,9))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Circular 9x9')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8ef0329810>,
#  <matplotlib.image.AxesImage at 0x7f8ef01e0e90>,
#  Text(0.5, 1.0, 'Citra Hasil Circular 9x9'))
